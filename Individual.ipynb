# %%
Year = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
Duration = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

Year_Duration_pairs = zip(Year, Duration)
movie_dict = dict (Year_Duration_pairs)
print(movie_dict)
# Out:
# {'2011': 103, '2012': 101, '2013': 99, '2014': 100, '2015': 100, '2016': 95, '2017': 95, '2018': 96, '2019': 93, '2020': 90}

# %% [markdown]
# Task 2

# %%
import pandas as pd 
movie_dict = {'Year':['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
'Duration':['103', '101', '99', '100', '100', '95', '95', '96', '93', '90']}
movie_dict_df = pd.DataFrame(movie_dict)
print(movie_dict_df)
# Out:
#    Year Duration
# 0  2011      103
# 1  2012      101
# 2  2013       99
# 3  2014      100
# 4  2015      100
# 5  2016       95
# 6  2017       95
# 7  2018       96
# 8  2019       93
# 9  2020       90

# %% [markdown]
# Task 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
Year = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
Duration = ['103', '101', '99', '100', '100', '95', '95', '96', '93', '90']
plt.plot(Year, Duration)
plt.title("Netflix Movie Durations 2011-2020")
plt.xlabel('Year')
plt.ylabel('Duration')
plt.show()
